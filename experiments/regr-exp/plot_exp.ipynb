# %%
import sys
sys.path.insert(0, '../..')

# %%
# %load_ext autoreload
# %autoreload 2

import tensorflow as tf
import matplotlib.pylab as plt
import os
import glob
from itertools import chain
from matplotlib import colors
import matplotlib
import numpy as np
import pandas as pd
import vardl



import matplotlib2tikz
from matplotlib2tikz import save as tikz_save
import sys
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # POWERPLANT

# %%
basedir = './work/powerplant/'
methods = ['blm', 'uninformative', 'heuristic', 'xavier-normal', 'lsuv', 'orthogonal']
plotter = vardl.utils.ExperimentPlotter(name='powerplant', 
                                        basedir=basedir, 
                                        methods=methods, 
                                        savepath='./figures/')

# %%
plotter.parse()
# Out:
# INFO - Parsing ./work/powerplant//blm/run-0004/events.out.tfevents.1536089700.py-notebook0-128-prod
# INFO - Parsing ./work/powerplant//blm/run-0005/events.out.tfevents.1536093619.py-notebook0-128-prod
# INFO - Parsing ./work/powerplant//blm/run-0001/events.out.tfevents.1536077914.py-notebook0-128-prod
# INFO - Parsing ./work/powerplant//blm/run-0003/events.out.tfevents.1536085764.py-notebook0-128-prod
# INFO - Parsing ./work/powerplant//blm/run-0002/events.out.tfevents.1536081837.py-notebook0-128-prod
# INFO - Parsing ./work/powerplant//uninformative/run-0004/events.out.tfevents.1536089700.py-notebook0-128-prod
# INFO - Parsing ./work/powerplant//uninformative/run-0005/events.out.tfevents.1536093619.py-notebook0-128-prod
# INFO - Parsing ./work/powerplant//uninformative/run-0001/events.out.tfevents.1536077914.py-notebook0-128-prod
# INFO - Parsing ./work/powerplant//uninformative/run-0003/events.out.tfevents.1536085765.py-notebook0-128-prod
# ...

# %%
matplotlib.rc_file('../../../dgp_rfs_svi_pytorch/config/whitepaper.mplrc')
plotter.plot(tags=['error/test', 'loss/test'], 
             xlim=[100, ], 
             ylims=[[0.2, 1], [-1, 1.5]], 
             xlog=True, 
             save=True)
plt.legend()
plt.show()
# Out:
# Bad key "axes.color_cycle" on line 242 in
# ../../../dgp_rfs_svi_pytorch/config/whitepaper.mplrc.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# INFO - Saving figure to './figures/powerplant.pdf'...
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:2299: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# INFO - Saving figure to './figures/powerplant.tex'...
# ...
# Please add the following lines to your LaTeX preamble:
#
# \usepackage[utf8]{inputenc}
# ...
